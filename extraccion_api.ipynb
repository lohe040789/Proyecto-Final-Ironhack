# %%
import requests

# Define las credenciales de tu aplicación
app_id = "f182b65b"
app_key = "4c99e07cbb4dfe20271a64d6c2981446"

# Define los parámetros de la consulta
calories = "100-500"  # cantidad de calorías que queremos que tenga cada porción

# Define la URL de la API y construye la solicitud HTTP
url = f"https://api.edamam.com/search?q=&app_id={app_id}&app_key={app_key}&calories={calories}"
response = requests.get(url)

# Procesa la respuesta de la API en formato JSON
data = response.json()

# Imprime los resultados (nombre y URL)
for recipe in data["hits"]:
    print(recipe["recipe"]["label"])
    print(recipe["recipe"]["url"])
    calories_per_serving = recipe["recipe"]["calories"] / recipe["recipe"]["yield"]
    print(f"Calorías por porción: {int(calories_per_serving)}")
    print("Ingredientes:")
    for ingredient in recipe["recipe"]["ingredientLines"]:
        print("- " + ingredient)
    print()
# Out:
# Strawberry Vodka
# http://www.davidlebovitz.com/strawberry-vodka-recipe-infusion/
# Calorías por porción: 132
# Ingredientes:
# - One bottle (750ml) vodka
# - 2 pints (about 1 1/4 pounds, 575g) strawberries, organic or unsprayed
#
# Easy Mango-Blackberry Smoothie Recipe
# http://www.seriouseats.com/recipes/2014/01/easy-mango-blackberry-kefir-smoothie-recipe.html
# Calorías por porción: 274
# Ingredientes:
# - 1 large ripe Ataulfo mango, peeled and roughly chopped (about 1 cup)
# - 1 cup plain unsweetened kefir
# - 1 cup frozen blackberries (4 1/2 ounces)
#
# Maple Banana Frozen Yogurt
# http://norecipes.com/blog/2008/04/26/maple-banana-frozen-yogurt/
# Calorías por porción: 123
# Ingredientes:
# - 2 rice bananas
# - 16 oz maple yogurt (I use Brown Cow Cream Top)
# - 1 tsp vanilla
#
# Vanilla Ice Cream With Grilled Corn And Lime
# http://ruhlman.com/2011/07/how-to-grill-corn/
# Calorías por porción: 166
# Ingredientes:
# - Good vanilla ice cream (about 1/2 cup per person, or as you wish)
# - Grilled corn (1/2 ear per person)
# - 1 lime (for every four servings)
#
# Roasted Strawberry Milkshake recipes
# http://notwithoutsalt.com/roasted-strawberry-milkshake/
# Calorías por porción: 157
# Ingredientes:
# - 8 cups halved strawberries
# - 1/4 – 1/3 cup sugar
# - 1 vanilla bean, split and seeds removed
#
# Fresh Lemon Syrup Recipe
# http://www.seriouseats.com/recipes/2016/03/fresh-lemon-syrup-recipe.html
# Calorías por porción: 241
# Ingredientes:
# - 15 ounces (2 1/2 cups; 425g) "used" lemon rinds, from 6 medium lemons or 12 Meyer lemons (see note above)
# - 7 ounces (1 cup; 200g) sugar
#
# Beer Vinegar
# http://ruhlman.com/2011/08/beer-vinegar-recipe/
# Calorías por porción: 204
# Ingredientes:
# - 1/2 gallon good, wheaty or malty beer
# - Vinegar mother (optional)
#
# Watermelon And Peach Fresh Fruit Cake
# http://notwithoutsalt.com/2014/05/30/watermelon-peach-fresh-fruit-cake/
# Calorías por porción: 208
# Ingredientes:
# - 1 small watermelon (for a 6 to 8-inch cake)
# - 2-3 peaches, thinly sliced
# - 1 cup fresh blueberries
#
# Imperial Royale Recipe
# http://www.seriouseats.com/recipes/2014/05/imperial-royale-bud-light-lime-st-germain-shandy-cocktail-recipe.html
# Calorías por porción: 292
# Ingredientes:
# - 1 (12 ounce) can or bottle Bud Light Lime, chilled
# - 2 ounces St. Germain elderflower liqueur
#
# The Rusty Nail
# http://ruhlman.com/2013/12/friday-cocktail-hour-rusty-nail/
# Calorías por porción: 111
# Ingredientes:
# - 2 ounces Scotch
# - 1 ounce Drambuie
# - 1 twist of lemon

# %%
import requests
import pandas as pd

# Define las credenciales de tu aplicación
app_id = "f182b65b"
app_key = "4c99e07cbb4dfe20271a64d6c2981446"

# Define los parámetros de la consulta
calories = "100-500"  # cantidad de calorías que queremos que tenga cada porción
max_results = 5  # número máximo de resultados que queremos obtener

# Define la URL de la API y construye la solicitud HTTP
url = f"https://api.edamam.com/search?q=&app_id={app_id}&app_key={app_key}&calories={calories}&to={max_results}"
response = requests.get(url)

# Procesa la respuesta de la API en formato JSON
data = response.json()

# Crea una lista de diccionarios para almacenar los datos de cada receta
recipes_data = []

# Itera sobre cada hit y almacena los datos de cada receta en la lista de diccionarios
for recipe in data["hits"]:
    recipe_data = {
        "Nombre": recipe["recipe"]["label"],
        "URL": recipe["recipe"]["url"],
        "Calorías por porción": int(recipe["recipe"]["calories"] / recipe["recipe"]["yield"]),
        "Ingredientes": recipe["recipe"]["ingredientLines"]
    }
    recipes_data.append(recipe_data)

# Crea un DataFrame a partir de la lista de diccionarios
df_recipes = pd.DataFrame(recipes_data)

# Muestra el DataFrame
df_recipes.head()
# Out:
#                                          Nombre  \
# 0                              Strawberry Vodka
# 1         Easy Mango-Blackberry Smoothie Recipe
# 2                    Maple Banana Frozen Yogurt
# 3  Vanilla Ice Cream With Grilled Corn And Lime
# 4          Roasted Strawberry Milkshake recipes
#
#                                                  URL  Calorías por porción  \
# 0  http://www.davidlebovitz.com/strawberry-vodka-...                   132
# 1  http://www.seriouseats.com/recipes/2014/01/eas...                   274
# 2  http://norecipes.com/blog/2008/04/26/maple-ban...                   123
# 3      http://ruhlman.com/2011/07/how-to-grill-corn/                   166
# 4  http://notwithoutsalt.com/roasted-strawberry-m...                   157
#
#                                         Ingredientes
# 0  [One bottle (750ml) vodka, 2 pints (about 1 1/...
# 1  [1 large ripe Ataulfo mango, peeled and roughl...
# 2  [2 rice bananas, 16 oz maple yogurt (I use Bro...
# 3  [Good vanilla ice cream (about 1/2 cup per per...
# 4  [8 cups halved strawberries, 1/4 – 1/3 cup sug...

# %%
df_recipes.shape
# Out:
# (100, 4)
